# %%
import requests

api_key = 'fr5dj7gDj4gZmxQo504MTw'
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
params = {
    'linkedin_profile_url': 'https://linkedin.com/in/tknishh/',

}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
print(response.json())
# Out:
# {'public_identifier': 'tknishh', 'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/tknishh/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231121%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231121T201206Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=e7f1138fce394bb20472b6c23e77a22e118347ab60c5ce5f0ce856e02912edc3', 'background_cover_image_url': None, 'first_name': 'Tanish', 'last_name': 'Khandelwal', 'full_name': 'Tanish Khandelwal', 'follower_count': None, 'occupation': 'Data Engineer Intern at Fintricity', 'headline': "Data Engineer Intern @Fintricity | Finalist @SIH'22 | Engage'22 @Microsoft | Test Automation Engineer", 'summary': "Hi there! I'm an aspiring data engineer who loves finding patterns and connecting dots: be it ideas from different industries, people from different backgrounds and teams, or applications from different industries. I have strong technical skills, particularly in databases and machine learning, and an academic background in mathematics, engineering and statistics.\n\nI love solving real-world problems with unique algorithms and communicating complex ideas to companies.\n\nIn my graduate studies, I took on a number of leadership roles, conducting sessions on Python and its applications in ML and coordinating club events for 200+ attendees.\n\nI'm graduating in July 2024 and I'm interested in part-time or internship opportunities in data engineering or machine learning engineer roles. Connect with me at tanishkhandelwaltk012@gmail.com\n\nProficient: Tableau, Python (scikit-learn, NumPy, SciPy, pandas), TensorFlow, keras, Excel, Snowflake, AWS, GCP, DataBricks\nKnowledgeable: R, MySQL, MongoDB, Hadoop, Spark, Airflow, Scala, Go, Python, Ansible\nFamiliar: NLP (Natural Language Processing), CNNs, Operations, Project Management, Distributed Systems", 'country': 'IN', 'country_full_name': 'India', 'city': 'Palghar', 'state': 'Maharashtra', 'experiences': [{'starts_at': {'day': 1, 'month': 2, 'year': 2023}, 'ends_at': None, 'company': 'Fintricity', 'company_linkedin_profile_url': 'https://www.linkedin.com/company/fintricity/', 'title': 'Data Engineer Intern', 'description': None, 'location': 'London, England, United Kingdom', 'logo_url': 'https://media.licdn.com/dms/image/C4E0BAQEbNJET8cw0_Q/company-logo_400_400/0/1568048614817?e=1696464000&v=beta&t=RH9eFO0A4CEdL1EVpq9nscdijrribvQqkdEbBE3rBvQ'}, {'starts_at': {'day': 1, 'month': 10, 'year': 2022}, 'ends_at': {'day': 1, 'month': 4, 'year': 2023}, 'company': 'QuoDeck Technologies Pvt. Ltd', 'company_linkedin_profile_url': 'https://www.linkedin.com/company/quodeck/', 'title': 'Intern', 'description': '- Collaborated with a number of teams, including the QA Team, Data Engineering, and Web Development.\n- Was in responsible for ensuring seamless operation and team switching.\n- Working closely with the data engineering and data analysis teams to extract unique insights from the data, and used a variety of ETL techniques to guarantee that the data was accessible to diverse teams.', 'location': 'Mumbai, Maharashtra, India', 'logo_url': 'https://media.licdn.com/dms/image/C4E0BAQG9Vu1O0Dhj7Q/company-logo_400_400/0/1519876201729?e=1696464000&v=beta&t=ZvX9BPhLKFqdMeQY8cdYhRKlHhCLh5IumsNZrRCoW-8'}, {'starts_at': {'day': 1, 'month': 8, 'year': 2022}, 'ends_at': {'day': 1, 'month': 1, 'year': 2023}, 'company': 'RecruitNXT', 'company_linkedin_profile_url': 'https://www.linkedin.com/company/recruitnxt/', 'title': 'Project Manager', 'description': "- Charged with overseeing and leading the company's automation testing staff.\n- Automated testing of the company's top SaaS product and a few additional items.\n- Made use of the Selenium, Java, and IntelliJ IDE to create scripts for test scenarios and unit test cases.", 'location': 'New Delhi, Delhi, India', 'logo_url': 'https://media.licdn.com/dms/image/C4D0BAQGPYHrGPocVOg/company-logo_400_400/0/1625089903557?e=1696464000&v=beta&t=8bpIHwFaq_ ...

# %%
import requests

api_key = 'GIKVvPMjTyGHwZIvLZ567A'
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 'https://nubela.co/proxycurl/api/linkedin/company/resolve'
params = {
    'company_domain': 'https://www.nike.com/',
}
response = requests.get(api_endpoint,
                        params=params,

                        headers=headers)

# %%
print(response.json())
# Out:
# {'url': 'https://www.linkedin.com/company/nike'}

# %%
api_endpoint = 'https://nubela.co/proxycurl/api/linkedin/company/employees/'
params = {
    'url': 'https://www.linkedin.com/company/nike',
    'country': 'us',
    'enrich_profiles': 'enrich',
    'role_search': '(co)?-?founder',
    'page_size': '10',
    'employment_status': 'current',
    'sort_by': 'recently-joined',
    'resolve_numeric_id': 'false',
}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
print(response.json())
# Out:
# {'employees': [{'profile_url': 'https://www.linkedin.com/in/julielangford', 'profile': {'public_identifier': 'julielangford', 'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/julielangford/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231121%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231121T201246Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=66fc785bdbd8c05275ea062055b31486d0361fd0e6ac8e5f47c9223ac565d89d', 'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/julielangford/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231121%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231121T201246Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=20b9a4302bf9776c60677b9c489dda60a9e37e91ab7daf900cd1e377572e9e6b', 'first_name': 'Julie', 'last_name': 'Langford', 'full_name': 'Julie Langford', 'follower_count': 2570, 'occupation': 'Stretch: Product-Led Transformation Director, North America Technology at Nike', 'headline': 'Director, Nike North America Technology | DEI & Health Advocate | Sandwich Gen', 'summary': "I'm a high-energy innovator and business transformer who passionately uses historic and current knowledge to drive future-focused business models that make our shared best better through new products, services, and societal impact. \u2028\u2028\n\nMy capabilities and experience tie to strategic planning and implementation, public speaking, knowledge-focused architectural design, third-party vendor negotiations, collaboration training design, and process optimization.\n\nMy career has focused on strategy and action-oriented positions in education, military, non-profit and sports. Passionate for volunteering, I am honored to have received the Presidential Volunteer Award (+35,000 hours). I'm especially proud of serving as volunteer marketing director during the creation of a free women's clinic in Colorado Springs, CO, a Team USA Olympic Team chaplain for 3 years, and most recently Nike's Women of STEM Network Co-Chair and stewarding DEI Taskforce efforts.\n\nAn insatiable learner, I learned early on that experience and listening is the key to knowledge. I've served as an educator/clinician hundreds of times over and have served as moderator and SME across numerous collaborative experiences.\n\nI am grateful for my education in Electronic Media/Film (Evangel University), and a M.S. in Information and Knowledge Strategy (Columbia University, ‘15). I received the Colorado Springs' Rising Star Award 2014 Young Professional under the age of 40, and served as Speaker Series Committee Chair for the Columbia University alumni IKNS COP.\n\nMy best friend (and husband) Andrew, our little guy Benjamin, gal Evelyn and I love living in Portland, Oregon, where I'm passionate to serve my community, explore outdoor adventures and other cultures, and invent a new kind of wheel (or reinvent the old one)!", 'country': 'US', 'country_full_name': 'United States of America', 'city': 'Portland', 'state': 'Oregon', 'experiences': [{'starts_at': {'day': 1, 'month': 9, 'year': 2022}, 'ends_at': None, 'company': 'Nike', 'company_linkedin_profile_url': 'https://www.linkedin.com/company/nike', 'title': 'Stretch: Product-Led Transformation Director, North America Technology', 'description': None, 'location': None, 'logo_url': 'https://media.licdn.com/dms/image/C560BAQFckBxRnPg53Q/company-logo_100_100/0/1561999707114?e=2147483647&v=beta&t=mKF3sZbRpO9_D855W9jddp-__9AUwpYARpnZSEkBNm8'}, {'starts_at': {'day': 1, 'month': 11, 'year': 2021}, 'ends_at': None, 'company': 'Nike', 'company_linkedin_profile_url': 'https://www.linkedin.com/company/nike', 'title': 'Co-Founder: Global Tech DEI Accelerator', 'description': None, 'location': None, 'logo_url': 'https://media.licdn.com/dms/image/C560BAQFckBxRnPg53Q/company-logo_100_100/0/1561999707114?e=2147483647&v=beta&t=mKF3sZbRpO9_D855W9jddp-__9AUwpYARpnZS ...

# %%
api_endpoint = 'https://nubela.co/proxycurl/api/linkedin/profile/email'
params = {
    'linkedin_profile_url': 'https://www.linkedin.com/in/julielangford',
    'callback_url': 'https://webhook.site/29e12f17-d5a2-400a-9d08-42ee9d83600a',
}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
print(response.json())
# Out:
# {'email_queue_count': 0}
